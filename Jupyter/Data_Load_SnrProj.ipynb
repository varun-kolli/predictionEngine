# %%
import pandas as pd

filename1 = 'mhcld-puf-2013-csv.csv'
df2013 = pd.read_csv(filename1)

# %%
df2013.head()
# Out:
#    YEAR  AGE  EDUC  ETHNIC  RACE  GENDER  SPHSERVICE  CMPSERVICE  OPISERVICE  \
# 0  2013    8     4      -9     6       2           2           1           2
# 1  2013    8    -9       4    -9       2           1           1           2
# 2  2013    6     3      -9     5       1           2           1           2
# 3  2013   10    -9       4    -9       1           1           2           2
# 4  2013    1    -9      -9     2       2           2           1           2
#
#    RTCSERVICE  ...  ODDFLG  PDDFLG  PERSONFLG  SCHIZOFLG  ALCSUBFLG  \
# 0           2  ...       0       0          0          0          0
# 1           2  ...       0       0          1          0          0
# 2           2  ...       0       0          0          0          0
# 3           2  ...       0       0          0          1          0
# 4           2  ...       0       0          0          0          0
#
#    OTHERDISFLG  STATEFIP  DIVISION  REGION       CASEID
# ...

# %%
filename2 = 'mhcld-puf-2014-csv.csv'
df2014 = pd.read_csv(filename2)

filename3 = 'mhcld-puf-2015-csv.csv'
df2015 = pd.read_csv(filename3)

filename4 = 'mhcld-puf-2016-csv.csv'
df2016 = pd.read_csv(filename4)

filename5 = 'mhcld-puf-2017-csv.csv'
df2017 = pd.read_csv(filename5)

filename6 = 'mhcld-puf-2018-csv.csv'
df2018 = pd.read_csv(filename6)

filename7 = 'mhcld-puf-2019-csv.csv'
df2019 = pd.read_csv(filename7)

# %%
frames = [df2013, df2014, df2015, df2016, df2017, df2018, df2019]
dfAllYears = pd.concat(frames)

# %%
dfAllYears
# Out:
#          YEAR  AGE  EDUC  ETHNIC  RACE  GENDER  SPHSERVICE  CMPSERVICE  \
# 0        2013    8     4      -9     6       2           2           1
# 1        2013    8    -9       4    -9       2           1           1
# 2        2013    6     3      -9     5       1           2           1
# 3        2013   10    -9       4    -9       1           1           2
# 4        2013    1    -9      -9     2       2           2           1
# ...       ...  ...   ...     ...   ...     ...         ...         ...
# 6548367  2019   10    -9      -9     5       1           1           2
# 6548368  2019    4    -9       3     1       1           2           2
# 6548369  2019   13     5       4     5       2           2           2
# 6548370  2019   11    -9       3     5       2           1           2
# 6548371  2019   14    -9       4    -9       2           2           1
#
#          OPISERVICE  RTCSERVICE  ...  ODDFLG  PDDFLG  PERSONFLG  SCHIZOFLG  \
# ...

# %%
dfAllYears = dfAllYears.dropna()

# %%
#when downloading use a pickle (.pkl)
dfAllYears.to_pickle("./mh-cld-all_years.pkl")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-10c2ad432b70> in <module>
#       1 #when downloading use a pickle (.pkl)
# ----> 2 dfAllYears.to_pickle("./mh-cld-all_years.pkl")
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/generic.py in to_pickle(self, path, compression, protocol, storage_options)
#    2960             compression=compression,
#    2961             protocol=protocol,
# -> 2962             storage_options=storage_options,
#    2963         )
#    2964
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/io/pickle.py in to_pickle(obj, filepath_or_buffer, compression, protocol, storage_options)
#     117                 obj,
#     118                 handles.handle,  # type: ignore[arg-type]
# --> 119                 protocol=protocol,
#     120             )
#     121
#
# ...

# %%
import pandas as pd
dfTest = pd.read_pickle('mh-cld-all_years.pkl')

# %%
dfTest.shape
# Out:
# (40626448, 40)
